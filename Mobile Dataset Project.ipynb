# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df =pd.read_csv(r"C:\Users\TASMIYA\Downloads\mobile datasets\mobile_sales 2.csv")

# %%
df.head(5)
# Out:
#                           TransactionID        Date MobileModel  \
# 0  79397f68-61ed-4ea8-bcb2-f918d4e6c05b  06-01-2024   direction
# 1  4f87d114-f522-4ead-93e3-f336402df6aa  05-04-2024       right
# 2  6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  13-02-2024      summer
# 3  7da7de95-f772-4cc2-bce0-b0873f98233e  17-04-2024        keep
# 4  469044af-0d60-4d87-af66-c6603e844057  02-06-2024      option
#
#               Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 0         Green Inc  1196.95         85      28002.80           32
# 1   Thomas-Thompson  1010.34         64       2378.82           55
# 2  Sanchez-Williams   400.80         95      31322.56           57
# 3    Greer and Sons   338.60         79      31159.75           46
# 4    Brown and Sons   839.79         41      11523.36           38
#
#   CustomerGender           Location PaymentMethod
# 0         Female          Port Erik        Online
# 1         Female         East Linda   Credit Card
# ...

# %%
df.size
# Out:
# 11000

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.dtypes
# Out:
# TransactionID      object
# Date               object
# MobileModel        object
# Brand              object
# Price             float64
# UnitsSold           int64
# TotalRevenue      float64
# CustomerAge         int64
# CustomerGender     object
# Location           object
# PaymentMethod      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TransactionID   1000 non-null   object
#  1   Date            1000 non-null   object
#  2   MobileModel     1000 non-null   object
#  3   Brand           1000 non-null   object
#  4   Price           1000 non-null   float64
#  5   UnitsSold       1000 non-null   int64
#  6   TotalRevenue    1000 non-null   float64
#  7   CustomerAge     1000 non-null   int64
#  8   CustomerGender  1000 non-null   object
#  9   Location        1000 non-null   object
#  10  PaymentMethod   1000 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#              Price    UnitsSold   TotalRevenue  CustomerAge
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean    807.512970    50.074000   40218.445040    41.141000
# std     402.489878    28.616804   32715.290358    13.528346
# min     103.320000     1.000000     116.850000    18.000000
# 25%     458.037500    25.000000   13316.037500    29.000000
# 50%     823.730000    51.000000   30860.655000    41.000000
# 75%    1157.875000    75.000000   60770.435000    53.000000
# max    1499.250000    99.000000  141411.840000    64.000000

# %%
df.PaymentMethod.unique()
# Out:
# array(['Online', 'Credit Card', 'Cash', 'Debit Card'], dtype=object)

# %%
sns.histplot(x='UnitsSold',data=df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='UnitsSold', ylabel='Count'>

# %%
def set_size_style(width, height, style=None):
    plt.figure(figsize=(width, height))
    if style != None:
        sns.set_style(style)
def customize_plot(plot, title:str, xlabel:str,  ylabel:str, title_font:int, label_font:int):
    plot.set_title(title, fontsize = title_font, weight='bold')
    plot.set_xlabel(xlabel, fontsize = label_font, weight='bold')
    plot.set_ylabel(ylabel, fontsize = label_font, weight='bold')

# %%
set_size_style(17,6,'dark')
ax= sns.barplot(data = df, x = 'Brand', y= 'UnitsSold',palette = 'Spectral')
plt.xticks(rotation=45)
customize_plot(ax,'Distribution of Smartphone Brands','Name of Brand', 'Number of Smartphones',12,10)
for c in ax.containers:
        ax.bar_label(c)

# %%
sns.relplot(x='UnitsSold',y='Price',data=df, kind='scatter',hue='Date',col='Date',col_wrap=4)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df
# Out:
#                             TransactionID       Date MobileModel  \
# 0    79397f68-61ed-4ea8-bcb2-f918d4e6c05b 2024-01-06   direction
# 1    4f87d114-f522-4ead-93e3-f336402df6aa 2024-04-05       right
# 2    6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1 2024-02-13      summer
# 3    7da7de95-f772-4cc2-bce0-b0873f98233e 2024-04-17        keep
# 4    469044af-0d60-4d87-af66-c6603e844057 2024-06-02      option
# ..                                    ...        ...         ...
# 995  41f08915-addb-4966-8628-038c479c619a 2024-01-28   challenge
# 996  bcfa1912-5bd8-4894-900f-376fa48f022d 2024-07-13       least
# 997  e6839305-a177-4cda-aada-3ac1f49eeeec 2024-01-13       enjoy
# 998  12f7ac32-9063-4ae5-a122-385b06ba77af 2024-01-25        half
# 999  d3e82026-2084-40f2-8d5d-d2a94a198af9 2024-01-17        fill
#
#                           Brand    Price  UnitsSold  TotalRevenue  \
# 0                     Green Inc  1196.95         85      28002.80
# ...

# %%
filtered_df = df[df['Date'].dt.month == 1]
filtered_df
# Out:
#                             TransactionID       Date MobileModel  \
# 0    79397f68-61ed-4ea8-bcb2-f918d4e6c05b 2024-01-06   direction
# 12   1a9dfe22-c8d8-4872-8cb3-1e7d37c492a9 2024-01-27     nothing
# 20   01ba7cfd-dc66-4825-9d40-3575f752c1cc 2024-01-02        wait
# 26   e59a8eb1-8448-4719-8502-2c97407d0ff9 2024-01-08        free
# 27   4a18ec65-d781-4e34-b8e2-f7efb3303e04 2024-01-25        name
# ..                                    ...        ...         ...
# 994  7b63f5e4-0252-447e-b7b7-15e73e437d31 2024-01-15       sport
# 995  41f08915-addb-4966-8628-038c479c619a 2024-01-28   challenge
# 997  e6839305-a177-4cda-aada-3ac1f49eeeec 2024-01-13       enjoy
# 998  12f7ac32-9063-4ae5-a122-385b06ba77af 2024-01-25        half
# 999  d3e82026-2084-40f2-8d5d-d2a94a198af9 2024-01-17        fill
#
#                            Brand    Price  UnitsSold  TotalRevenue  \
# 0                      Green Inc  1196.95         85      28002.80
# ...

# %%
sns.lineplot(x='Date',y='UnitsSold',data=filtered_df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date', ylabel='UnitsSold'>

# %%
sns.lineplot(x='Date', y='UnitsSold',data=df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date', ylabel='UnitsSold'>

# %%
sns.scatterplot(x='Price',y='CustomerAge',data= df, style='PaymentMethod',hue='CustomerGender')
# Out:
# <Axes: xlabel='Price', ylabel='CustomerAge'>

# %%
plt.figure(figsize=(12,8))
plt.scatter(df['Price'],df['UnitsSold'])

# %%
#top 5 prices sorting
top_5_prices = df.sort_values(by='Price', ascending=False).head(5)
top_5_prices
# Out:
#                             TransactionID       Date MobileModel  \
# 618  0cea2fc6-9c78-4e30-9f11-8a902c60809c 2024-06-05     company
# 5    f7e98db9-cb87-453e-8179-e48ba5443932 2024-03-07        idea
# 711  67181c30-af64-49bc-b730-65c38b38575c 2024-02-19      friend
# 787  919c1ad3-a1e4-417b-8de2-857999657de7 2024-04-14       could
# 785  6ad81fed-c3a4-4c01-b1f0-ee7ad6696755 2024-05-19       speak
#
#                            Brand    Price  UnitsSold  TotalRevenue  \
# 618   Pierce, Schaefer and Walsh  1499.25         49      11024.64
# 5    Massey, Nicholson and Young  1498.13         70       9703.89
# 711                  Delgado Ltd  1497.89         62      57220.15
# 787      Evans, Clayton and Ross  1494.78         56      25845.56
# 785                  Morales LLC  1494.45         42      63030.92
#
#      CustomerAge CustomerGender         Location PaymentMethod
# 618           44           Male     South Leslie   Credit Card
# ...

# %%
df.Price.sort_values(ascending=False).head(5)
# Out:
# 618    1499.25
# 5      1498.13
# 711    1497.89
# 787    1494.78
# 785    1494.45
# Name: Price, dtype: float64

# %%
# plot of 5  highest date (unitsold)
plt.plot(top_5_prices['Date'],top_5_prices['UnitsSold'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(top_5_prices['Price'],top_5_prices['UnitsSold'],marker ='^', s=top_5_prices['CustomerAge'],color="#66D148")

# %%
plt.bar(df['CustomerGender'],df['TotalRevenue'],data=df)
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.figure(figsize=(10,6))
plt.scatter(top_5_prices['Price'],top_5_prices['UnitsSold'])
for i in range(len(top_5_prices.MobileModel)):
    plt.text(top_5_prices['Price'].values[i], top_5_prices['UnitsSold'].values[i],top_5_prices['MobileModel'].values[i],fontdict = {'family': 'serif','color':'darkred','weight': 'bold','size':10})
    #above 60 values
    plt.axhline(60,color='g')
    plt.axvline(1497,color='r')

# %%
plt.figure(figsize=(18,10))
plt.scatter(top_5_prices['CustomerGender'], top_5_prices['TotalRevenue'])
 
for i in range(len(top_5_prices.Brand)):
        plt. text(top_5_prices['CustomerGender'].values[i], top_5_prices['TotalRevenue'].values[i], top_5_prices['Brand'].values[i])

# %%
sns.histplot(x= 'CustomerAge',data =df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='CustomerAge', ylabel='Count'>

# %%
plt.pie(top_5_prices['CustomerAge'].value_counts(),labels =top_5_prices['CustomerAge'].unique(), autopct= '%.4f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2325ce72690>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, '44'),
#   Text(-0.3399187231970732, 1.046162158377023, '45'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, '30'),
#   Text(-0.33991862524830174, -1.0461621902025062, '38'),
#   Text(0.8899187482945414, -0.6465637025335375, '55')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.0000'),
#   Text(-0.18541021265294902, 0.5706339045692853, '20.0000'),
#   Text(-0.5999999999999993, -2.808802703071063e-08, '20.0000'),
#   Text(-0.1854101592263464, -0.5706339219286397, '20.0000'),
#   Text(0.4854102263424771, -0.3526711104728386, '20.0000')])

# %%
fig, ax = plt.subplots(nrows=2,ncols=1)
ax[0].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'], color='green')
ax[0].set_title("top_5_prices_TotalRevenue")
ax[0].set_xlabel('h')

ax[1].scatter(top_5_prices['CustomerGender'],top_5_prices['Brand'],color='red')
#ax[1].set_title("top_5_prices")
ax[1].set_xlabel('h')

plt.show()

# %%
fig, ax = plt.subplots(nrows=2,ncols=2)
ax[0][0].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'])
ax[0][1].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'])
ax[1][0].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'])
ax[1][1].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'])

# %%
fig, ax = plt.subplots(nrows=2,ncols=2)
#plt.title('Title')
ax[0][0].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'],color='green')
ax[0][0].set_title("TotalRevenue")
ax[0][0].set_xlabel('h')


ax[0][1].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'],color='red')
#ax[1].set_title("CustomerGender")
ax[0][1].set_ylabel('h')

ax[1][0].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'])
ax[1][0].set_title("TotalRevenue")
#ax[2].set_xlabel('h')

#ax[3].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'],colo='pink')
#ax[3].set_title("TotalRevenue")
#ax[3].set_xlabel('h')

ax[1][1].scatter(top_5_prices['CustomerGender'],top_5_prices['TotalRevenue'],color='yellow')
ax[1][1].set_title("TotalRevenue")
ax[1][1].set_xlabel('h')


plt.show()

# %%
#top 5 Brand sorting
top_5_Brand = df.sort_values(by='Brand', ascending=False).head(5)
top_5_Brand
# Out:
#                             TransactionID        Date MobileModel  \
# 917  f507de10-0f04-44a3-8057-d114578829d9  16-06-2024       visit
# 359  2f93bcf2-cf72-4978-9688-bf2110921b91  21-04-2024         pay
# 156  baefeff0-2f10-4ab3-81fe-50e61276494f  14-04-2024    director
# 719  15b09d84-166a-4a3d-a92b-d6cddc7e46cf  15-05-2024  experience
# 52   c3c81cda-10de-404e-96d3-7e0dc906f373  05-02-2024       never
#
#                          Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 917  Zhang, Bailey and Burnett  1481.70         32      56157.80           36
# 359                   Yu-Smith   176.36         25      42193.32           32
# 156     Young, Hill and Morgan   158.46          6       7755.77           42
# 719                  Young Inc  1341.15         93      99642.96           55
# 52                    York Inc   680.70         34      64526.30           23
#
#     CustomerGender       Location PaymentMethod
# 917           Male     Rojasmouth          Cash
# ...

# %%
df.Brand.sort_values(ascending= False).head(5)
# Out:
# 917    Zhang, Bailey and Burnett
# 359                     Yu-Smith
# 156       Young, Hill and Morgan
# 719                    Young Inc
# 52                      York Inc
# Name: Brand, dtype: object

# %%
plt.figure(figsize=(10,6))
plt.scatter(top_5_Brand['Brand'],top_5_Brand['UnitsSold'],marker ='x', s=top_5_Brand['CustomerAge'],color="red")

# %%
plt.figure(figsize=(8,4))
plt.hist(top_5_Brand['Brand'],bins=10,color='red',edgecolor="yellow",linewidth=0.2)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(8,4))
plt.hist(top_5_Brand['Price'],bins=18)
for i in range(len(top_5_Brand.MobileModel)):
    plt.text(top_5_Brand['Price'].values[i], top_5_Brand['UnitsSold'].values[i],top_5_Brand['Brand'].values[i],fontdict = {'family': 'serif','color':'darkred','weight': 'bold','size':10})
    #above 60 values
    plt.axhline(200,color='y')
    plt.axvline(1497,color='b')

# %%
#top brand using by customergender
plt.figure(figsize=(18,10))
plt.scatter(top_5_Brand['CustomerGender'], top_5_Brand['TotalRevenue'])
 
for i in range(len(top_5_Brand.Brand)):
        plt. text(top_5_Brand['CustomerGender'].values[i], top_5_Brand['TotalRevenue'].values[i], top_5_Brand['Brand'].values[i])

# %%
fig, ax = plt.subplots(nrows=2, ncols= 1)
#here i have used stair plot for incresaing brand rate.
ax[0].stairs(top_5_Brand['Brand'],linewidth=0.9)
ax[0].set_title("Increasing brand")
#ax[0].set_xlabel('h')

#here i have used stem plot for knowing the customergender who have used more particular brand.
ax[1].bar(top_5_Brand['Brand'],top_5_Brand['CustomerGender'],edgecolor="green",linewidth=0.6)
ax[1].set_title("brand by customergender")
ax[1].set_xlabel('h')

plt.show()

# %%
fig,ax = plt.subplots(nrows=2, ncols= 1,figsize=(9,6))
ax[0].boxplot(top_5_Brand['TotalRevenue'],widths=1.5)
ax[0].set_title("totalrevenue")

ax[1].boxplot(top_5_Brand['Price'],widths=1.5)
ax[1].set_title("Price")
# Out:
# Text(0.5, 1.0, 'Price')

# %%
top_5_Brand.MobileModel.unique()
# Out:
# array(['visit', 'pay', 'director', 'experience', 'never'], dtype=object)

# %%
fig,ax =plt.subplots(nrows=2,ncols=1)
ax[0].scatter(top_5_Brand['CustomerGender'],top_5_Brand['MobileModel'],color='green')
ax[0].set_title("more used models by gender")
plt.axhline(2,color='y')
plt.axvline(10,color='b')

ax[1].scatter(top_5_Brand['CustomerGender'],top_5_Brand['Location'],color='red')
ax[1].set_title("CustomerGender used more location")
#plt.axhline(2,color='y')
#plt.axvline(1,color='b')
plt.show()

# %%
plt.bar(df.UnitsSold.unique(),df.UnitsSold.value_counts())
# Out:
# <BarContainer object of 99 artists>

# %%
# age greater then 50 
df[df['CustomerAge']>50]
# Out:
#                             TransactionID       Date MobileModel  \
# 1    4f87d114-f522-4ead-93e3-f336402df6aa 2024-04-05       right
# 2    6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1 2024-02-13      summer
# 11   c28cafd9-08a6-4a72-8a89-b05d82993315 2024-02-18        very
# 14   72122aaf-4049-4799-9c5e-56fa0bda637a 2024-07-02       admit
# 17   f0e76c4a-2a03-4c2d-821c-114e2877fa0d 2024-07-13        have
# ..                                    ...        ...         ...
# 984  8c0faa71-8f95-43f8-9ab7-463a63eaee73 2024-05-22        like
# 985  9d1f033a-a271-475b-97ff-c85f667a334e 2024-02-26        fill
# 987  78570e53-00a1-4890-94bf-ded05ed52867 2024-01-22     prepare
# 992  fcf20873-f45d-4ae1-ba0a-6333c35a01f6 2024-01-23       watch
# 993  c6e776aa-f19e-4f86-b35e-4435b0725292 2024-02-11      memory
#
#                 Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 1     Thomas-Thompson  1010.34         64       2378.82           55
# ...

# %%
plt.bar(df.CustomerAge.unique(),df.CustomerAge.value_counts())
# Out:
# <BarContainer object of 47 artists>

# %%
df[df['TransactionID'].isna()]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, MobileModel, Brand, Price, UnitsSold, TotalRevenue, CustomerAge, CustomerGender, Location, PaymentMethod]
# Index: []

# %%
#To find duplicate values of transaction id.
df = pd.get_dummies(df, columns=['TransactionID'])
df
# Out:
#           Date MobileModel                       Brand    Price  UnitsSold  \
# 0   2024-01-06   direction                   Green Inc  1196.95         85
# 1   2024-04-05       right             Thomas-Thompson  1010.34         64
# 2   2024-02-13      summer            Sanchez-Williams   400.80         95
# 3   2024-04-17        keep              Greer and Sons   338.60         79
# 4   2024-06-02      option              Brown and Sons   839.79         41
# ..         ...         ...                         ...      ...        ...
# 995 2024-01-28   challenge                  Brooks Ltd  1386.69         76
# 996 2024-07-13       least       Lang, Brown and Stone  1159.26         59
# 997 2024-01-13       enjoy  Atkinson, Moore and Nelson   544.31         59
# 998 2024-01-25        half      Kim, Maxwell and Moore   331.98         84
# 999 2024-01-17        fill                 Wallace LLC   973.97         79
#
#      TotalRevenue  CustomerAge CustomerGender           Location  \
# ...

# %%
# Here i have used labelencoder to convert string values of customergender and payment method into integer values.
le = LabelEncoder()
df['CustomerGender'] = le.fit_transform(df['CustomerGender'])
df['PaymentMethod'] = le.fit_transform(df['PaymentMethod'])

# %%
ax= sns.barplot(data =top_5_Brand , x = 'Brand', y= 'UnitsSold',palette = 'Spectral')
plt.xticks(rotation=45)
customize_plot(ax,'Distribution of Smartphone Brands','Name of Brand', 'Number of Smartphones',12,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[215], line 3
#       1 ax= sns.barplot(data =top_5_Brand , x = 'Brand', y= 'UnitsSold',palette = 'Spectral')
#       2 plt.xticks(rotation=45)
# ----> 3 customize_plot(ax,'Distribution of Smartphone Brands','Name of Brand', 'Number of Smartphones',12,10)
#
# NameError: name 'customize_plot' is not defined

# %%
df
# Out:
#           Date MobileModel                       Brand    Price  UnitsSold  \
# 0   2024-01-06   direction                   Green Inc  1196.95         85
# 1   2024-04-05       right             Thomas-Thompson  1010.34         64
# 2   2024-02-13      summer            Sanchez-Williams   400.80         95
# 3   2024-04-17        keep              Greer and Sons   338.60         79
# 4   2024-06-02      option              Brown and Sons   839.79         41
# ..         ...         ...                         ...      ...        ...
# 995 2024-01-28   challenge                  Brooks Ltd  1386.69         76
# 996 2024-07-13       least       Lang, Brown and Stone  1159.26         59
# 997 2024-01-13       enjoy  Atkinson, Moore and Nelson   544.31         59
# 998 2024-01-25        half      Kim, Maxwell and Moore   331.98         84
# 999 2024-01-17        fill                 Wallace LLC   973.97         79
#
#      TotalRevenue  CustomerAge  CustomerGender           Location  \
# ...

# %%
def set_size_style(width, height, style=None):
    plt.figure(figsize=(width, height))
    if style != None:
        sns.set_style(style)
def customize_plot(plot, title:str, xlabel:str,  ylabel:str, title_font:int, label_font:int):
    plot.set_title(title, fontsize = title_font, weight='bold')
    plot.set_xlabel(xlabel, fontsize = label_font, weight='bold')
    plot.set_ylabel(ylabel, fontsize = label_font, weight='bold')

# %%
set_size_style(17,6,'dark')
ax= sns.barplot(data = top_5_Brand, x = 'Brand', y= 'UnitsSold',palette = 'Spectral')
plt.xticks(rotation=45)
customize_plot(ax,'Distribution of Smartphone Brands','Name of Brand', 'Number of Smartphones',12,10)
#for c in ax.containers:
        #ax.bar_label(c)

# %%
sns.relplot(x='UnitsSold',y='Price',data=top_5_Brand, kind='scatter',hue='Date')
